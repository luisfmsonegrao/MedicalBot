# %%
import os, sys

# %%
src_dir = os.path.abspath(os.path.join(os.getcwd(), os.pardir, "src"))
if src_dir not in sys.path:
    sys.path.append(src_dir)

# %%
from agent_ui.medicalbot_ui import demo
# Out:
# c:\Users\negra\mymlprojects\medicalbot\src\agent_ui\medicalbot_ui.py:64: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style dictionaries with 'role' and 'content' keys.
#   chatbot = gr.Chatbot()

# %%
demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
