# %%
import sys
import os

# %%
src_dir = os.path.abspath(os.path.join(os.getcwd(),os.pardir,'src'))
if src_dir not in sys.path:
    sys.path.append(src_dir)

# %%
from orchestrator import orchestrate
# Out:
# c:\Users\negra\mymlprojects\loka\src\orchestrator.py:18: SyntaxWarning: invalid escape sequence '\.'
#   model = joblib.load(".\..\models\decision_tree_classifier_small.joblib")

# %% [markdown]
# Test QA task

# %%
query = "Tell me how many procedures Jane Smith has been submitted to"
answer = orchestrate(query)
answer

# %% [markdown]
# Test prediction task

# %%
query = "What's the class of Chronic Obstructive Pulmonary Disease for a 65 year old man with a body-mass index of 40%"
answer = orchestrate(query)
answer
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[5], line 2
#       1 query = "What's the class of Chronic Obstructive Pulmonary Disease for a 65 year old man with a body-mass index of 40%"
# ----> 2 answer = orchestrate(query)
#       3 answer
#
# File c:\Users\negra\mymlprojects\loka\src\orchestrator.py:28, in orchestrate(query)
#      25 def orchestrate(query):
#      26     """Orchestrate DataDoctor agent"""
# ---> 28     task = get_task(query)#maybe this step can use smaller model specialized to text classification
#      29     features = task.get('features',{})
#      30     if task.get('task') == 'prediction':
#
# File c:\Users\negra\mymlprojects\loka\src\orchestrator.py:81, in get_task(query)
#      46 prompt = f"""
#      47 You are an assistant. Execute the following steps:
#      48
#    (...)
#      78 Query: "{query}"
#      79 """
#      80 answer = call_llm(prompt)
# ---> 81 task = json.loads(answer)
#      82 return task
#
# File c:\Users\negra\AppData\Local\Programs\Python\Python312\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File c:\Users\negra\AppData\Local\Programs\Python\Python312\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File c:\Users\negra\AppData\Local\Programs\Python\Python312\Lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 7 column 12 (char 105)

# %% [markdown]
# Test database query task

# %%
query = "How many urban men older than 40 and bmi lower than 20 are there?"
answer = orchestrate(query)
answer
