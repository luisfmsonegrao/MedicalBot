# %%
import sys
import os

# %%
src_dir = os.path.abspath(os.path.join(os.getcwd(), os.pardir, "src"))
if src_dir not in sys.path:
    sys.path.append(src_dir)

# %%
from agent.orchestrator import orchestrate
# Out:
# c:\Users\negra\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:11: UserWarning: A NumPy version >=1.23.5 and <2.3.0 is required for this version of SciPy (detected version 2.3.5)
#   from scipy.sparse import csr_matrix, issparse

# %% [markdown]
# Test QA task

# %%
query = "Tell me how many procedures Jane Smith has been submitted to"
answer = orchestrate(query,"1234","556556")
answer

# %% [markdown]
# Test prediction task

# %%
query = "What's the COPD class for a 20 year old woman who does not smoke "
answer = orchestrate(query,"1234","3456")
answer
# Out:
# (({'text': "Here's the data for query SELECT chronic_obstructive_pulmonary_disease FROM patient_data WHERE age = 20 AND sex = 'Female' AND smoker = 'No';:",
#    'data': {'chronic_obstructive_pulmonary_disease': ['D',
#      'D',
#      'B',
#      'A',
#      'B',
#      'D',
#      'C',
#      'C',
#      'D',
#      'B',
#      'C',
#      'A',
#      'A',
#      'C',
#      'D',
#      'A',
#      'A',
#      'B',
#      'C',
#      'B',
#      'D',
#      'C',
#      'C',
#      'C',
#      'A',
#      'B',
#      'D',
#      'A',
#      'A',
#      'C',
#      'A',
#      'A',
#      'C',
#      'B',
#      'C',
#      'D',
#      'B',
#      'C',
#      'B',
#      'B',
#      'B',
#      'B',
#      'C',
#      'B',
#      'D',
#      'B',
#      'C',
#      'C']}},
#   {'query': "What's the class of COPD class for a 20 year old woman who does not smoke ",
#    'results': {'text': "Here's the data for query SELECT chronic_obstructive_pulmonary_disease FROM patient_data WHERE age = 20 AND sex = 'Female' AND smoker = 'No';:",
#     'data': {'chronic_obstructive_pulmonary_disease': ['D',
#       'D',
#       'B',
#       'A',
#       'B',
#       'D',
#       'C',
#       'C',
#       'D',
#       'B',
#       'C',
#       'A',
#       'A',
#       'C',
#       'D',
#       'A',
#       'A',
#       'B',
#       'C',
#       'B',
#       'D',
#       'C',
#       'C',
#       'C',
#       'A',
#       'B',
#       'D',
#       'A',
#       'A',
#       'C',
#       'A',
#       'A',
#       'C',
#       'B',
#       'C',
#       'D',
#       'B',
#       'C',
#       'B',
#       'B',
#       'B',
#       'B',
#       'C',
#       'B',
#       'D',
#       'B',
#       'C',
#       'C']}},
#    'timestamp': 1765125721,
#    'context': [],
#    'task': 'db_query',
#    'query_id': '1234',
#    'session_id': '3456',
#    'features': "SELECT chronic_obstructive_pulmonary_disease FROM patient_data WHERE age = 20 AND sex = 'Female' AND smoker = 'No';",
#    'task_status': True,
#    'durations_dict': {'intent_duration': 1.0307510000002367,
#     'pred_duration': 0,
#     'context_duration': 0,
#     'qa_duration': 0,
#     'dbquery_duration': 2.1198402999998507},
#    'error_name': '',
#    'model_metadata': {'Model_name': 'COPD_Classifier',
#     'version': 1,
#     'run_id': 'c5b4160dc8b04108b08821e566ea711f'}}),
#  3.150610800001232)

# %% [markdown]
# Test database query task

# %%
query = "How many urban men older than 40 and bmi lower than 20 are there?"
answer = orchestrate(query)
answer
