# %%
import gradio as gr
import requests

# %%
API_URL = 'https://a83rxleacg.execute-api.us-east-1.amazonaws.com/datadoctor-chat'

# %%
def chat_fn(user_message,history):
    r = requests.post(API_URL, json={"query": user_message})
    answer = r.json().get("answer", "Error")
    history.append((user_message, answer))
    return history,history

# %%
with gr.Blocks() as demo:
    gr.Markdown("# 🤖 Bedrock RAG Chat via Lambda")
    chatbot = gr.Chatbot()
    msg = gr.Textbox(placeholder="Ask something...")
    msg.submit(chat_fn, [msg, chatbot], [chatbot, chatbot])
# Out:
# C:\Users\negra\AppData\Local\Temp\ipykernel_46528\2456475422.py:3: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style dictionaries with 'role' and 'content' keys.
#   chatbot = gr.Chatbot()

# %%
demo.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * Running on public URL: https://57b89823e0c8d557f0.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://57b89823e0c8d557f0.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
demo.close()
# Out:
# Closing server running on port: 7861
